# %%
import geopandas as gp

# %%
import pandas as pd
import numpy as np

# %%
world = gp.read_file(gp.datasets.get_path('naturalearth_lowres'))

# %%
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# ...

# %%
pollution = pd.read_csv('mismanaged-plastic-waste.csv')

# %%
pollution = pollution.rename(columns = {'Code': 'iso_a3'})
pollution
# Out:
#                   Entity    iso_a3  Year  \
# 0                Albania       ALB  2010
# 1                Algeria       DZA  2010
# 2                 Angola       AGO  2010
# 3               Anguilla       AIA  2010
# 4    Antigua and Barbuda       ATG  2010
# ..                   ...       ...   ...
# 182              Vanuatu       VUT  2010
# 183            Venezuela       VEN  2010
# 184              Vietnam       VNM  2010
# 185                World  OWID_WRL  2010
# 186                Yemen       YEM  2010
#
#      Total mismanaged plastic waste in 2010
# 0                                     29705
# 1                                    520555
# 2                                     62528
# 3                                        52
# 4                                      1253
# ..                                      ...
# 182                                   22478
# 183                                  102333
# 184                                 1833819
# ...

# %%
data = world.merge(pollution, on = 'iso_a3')
data
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2     35623680  North America                    Canada    CAN   1674000.0
# 3    326625791  North America  United States of America    USA  18560000.0
# 4      6909701        Oceania          Papua New Guinea    PNG     28020.0
# ..         ...            ...                       ...    ...         ...
# 123    6653210         Africa                     Libya    LBY     90890.0
# 124     865267         Africa                  Djibouti    DJI      3345.0
# 125    3856181         Europe          Bosnia and Herz.    BIH     42530.0
# 126     642550         Europe                Montenegro    MNE     10610.0
# 127    1218208  North America       Trinidad and Tobago    TTO     43570.0
#
#                                               geometry  \
# ...

# %%
data.to_file("countries_plastic_pollution.geojson", driver='GeoJSON')
